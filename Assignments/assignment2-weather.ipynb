# %% [markdown]
# # Assignment 2 : Weather
#
# This juypter notbook contains the first assignment for Programming for Data analytics.
#
# ## Author:
#  Grace Mary Smyth
#
# ## Lecturer:
# Andrew Beatty.
#
# The purpose of this notebook is to plot drybulb temperature in celsius over time.

# %% [markdown]
# ### First import pandas and matplotlib.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### import CSV

# %%
import csv

# %% [markdown]
# ### Import CSV file from folder in the PFDA-courseware repository

# %%
FILENAME= "weatherreadings.csv"
DATADIR= "../Assignments/"

# %% [markdown]
# ### open data set with reader

# %%
url = "https://raw.githubusercontent.com/andrewbeattycourseware/PFDA-courseware/7533f0fe1e5cfd2801accba0c0953d969f44c8ef/assignment/weatherreadings1.csv"

df = pd.read_csv(url)

# %% [markdown]
# ### Data is loaded. Now to look at it

# %%
df
# Out:
#                                   siteId        reportStartDateTime  \
# 0   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:15:00+00:00
# 1   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:45:00+00:00
# 2   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:00:00+00:00
# 3   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:15:00+00:00
# 4   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:30:00+00:00
# ..                                   ...                        ...
# 84  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:00:00+00:00
# 85  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:15:00+00:00
# 86  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:30:00+00:00
# 87  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:45:00+00:00
# 88  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T15:00:00+00:00
#
#             reportEndDateTime  collectionName  isPublic  isLatestVersion  \
# 0   2024-10-02T16:15:00+00:00               1      True             True
# ...

# %% [markdown]
# ### Validate the data types of columns in the CSV file

# %%
df.dtypes
# Out:
# siteId                             object
# reportStartDateTime                object
# reportEndDateTime                  object
# collectionName                      int64
# isPublic                             bool
# isLatestVersion                      bool
# observationType                     int64
# softwareType                       object
# windDirection                       int64
# relativeHumidity                  float64
# windSpeed_MilePerHour             float64
# windSpeed_MetrePerSecond          float64
# dryBulbTemperature_Fahrenheit     float64
# dryBulbTemperature_Celsius        float64
# wetBulbTemperature_Fahrenheit     float64
# wetBulbTemperature_Celsius        float64
# rainfallAmount_Inch                 int64
# rainfallAmount_Millimetre           int64
# rainfallRate_InchPerHour            int64
# rainfallRate_MillimetrePerHour      int64
# airPressure_InchOfMercury         float64
# airPressure_Hectopascal           float64
# ...

# %% [markdown]
# convert strings to dates using the pandas pd.to_datetime() function

# %%
df['createdDateTime'] = pd.to_datetime(df['createdDateTime'])

# %% [markdown]
# ### Plotting the data

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['createdDateTime'], df['dryBulbTemperature_Celsius'], marker='o', color='r')
plt.title('Dry Bulb Temperature Over Time',fontdict={'fontweight':'bold', 'fontsize': 26})
plt.xlabel('Created Date Time, October 2024, Dates: 02-03')
plt.ylabel('Temperature (°C)')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# From the above graph we can see the data in 2024 over an approx 24 hour period dated 02-03 of October. We can see that the dry bulb temperature is higher during daylight hours.

# %% [markdown]
# ## References
#
# https://www.datacamp.com/tutorial/pandas-read-csv?utm_source=google&utm_medium=paid_search&utm_campaignid=19589720824&utm_adgroupid=157156376311&utm_device=c&utm_keyword=&utm_matchtype=&utm_network
#
# https://realpython.com/pandas-python-explore-dataset/
#
# https://matplotlib.org/stable/tutorials/pyplot.html
